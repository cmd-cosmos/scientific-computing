# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr = np.array([
    [1, 2],
    [3, 4],
])

arr
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
arr.shape
# Out:
# (2, 2)

# %%
def print_matrix(matrix):
    for row in matrix:
        for val in row:
            print(val, end=" ")
        print()

print_matrix(matrix=arr)
# Out:
# 1 2
# 3 4

# %%
vec = np.array([1,1])

# vector matrix mult
'''
1  1 x  1  2  = (1+3) (2+4) = 4 6
        3  4
'''
vec @ arr
# Out:
# array([4, 6])
